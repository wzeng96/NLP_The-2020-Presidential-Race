# %%
import pandas as pd
import numpy as np
import os
import glob  # try 'sudo pip3 install glob3' if you don't have the glob module in your python

# %%
def filter_df(orig_df):
    
    # remove rows where any of its value is null
    df_clean = orig_df.dropna(how = 'any', axis = 0)
    
    # rename news media name to maintain consistancy
    df_clean = df_clean.replace('The New York Times', 'New York Times')
    df_clean = df_clean.replace('Wall Street Journal (Online)', 'Wall Street Journal')
    
    # remove rows where the value of ['media'] is not media name
    df_clean = df_clean[(df_clean['media'] == "New York Times") | 
                        (df_clean['media'] == "Wall Street Journal") |
                        (df_clean['media'] == "The Washington Post")]
    
    return df_clean

# %%
# define a function to process all news articles for one individual candiate
def individual_candidate_articles(path, candidate_name):
    # change current directory path
    os.chdir(path)
    
    # set extension and collect all file names
    extension = 'csv'
    all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
    
    # combine all files in the list
    df = pd.concat([pd.read_csv(f, header = 0, engine="python") for f in all_filenames], sort=False)
    
    # select relevant columns to work with
    df = df[['title', 'text', 'media', 'word_count']]

    # add a feature indicating this df is designated for Sanders or Trump or Biden
    df['candidate_name'] = candidate_name

    cleaned_df = filter_df(df)

    unique_media_names = cleaned_df['media'].unique()
    
    return cleaned_df, unique_media_names

# %%
# create a balanced dataset for each candidate
def balanced_dataset(df, num):
    filter1 = df[df['media'] == 'New York Times'][0:num]
    filter2 = df[df['media'] == 'The Washington Post'][0:num]
    filter3 = df[df['media'] == 'Wall Street Journal'][0:num]
    
    df_concat = pd.concat([filter1, filter2, filter3])
    
    return df_concat

# %% [markdown]
# ## Bernie Sanders

# %%
# Please modify the path to your own directory
PATH_Sanders = "C:/Users/Winnie/Documents/2020 Spring/NLP/Final Project/Data/Sanders" 
CANDIDATE_NAME_Sanders = 'Bernie Sanders'
dfSanders, unique_names = individual_candidate_articles(PATH_Sanders, CANDIDATE_NAME_Sanders)
dfSanders.head(2)
# Out:
#                                                title  \
# 0  A Sign of the Times? The Democratic Primary Ha...
# 1  Tops in Iowa, Under Attack At Every Turn: [Nat...
#
#                                                 text           media  \
# 0  Hide highlightingFull TextTranslateUndo Transl...  New York Times
# 1  Hide highlightingFull TextTranslateUndo Transl...  New York Times
#
#    word_count  candidate_name
# 0      1122.0  Bernie Sanders
# 1      1995.0  Bernie Sanders

# %%
nNYT = len(dfSanders[dfSanders['media'] == 'New York Times'])
nTWP = len(dfSanders[dfSanders['media'] == 'The Washington Post'])
nWSJ = len(dfSanders[dfSanders['media'] == 'Wall Street Journal'])
n_total = len(dfSanders)

print('The unique news media company names are:', unique_names, 
      '. We scrapped a total of', n_total, 
      'articles associated with Bernie Sanders. Among those articles,',
      nNYT, 'are sourced from the New York Times;',
      nTWP, 'are sourced from The Washington Post; and',
      nWSJ, 'are sourced from the Wall Street Journal.')
# Out:
# The unique news media company names are: ['New York Times' 'The Washington Post' 'Wall Street Journal'] . We scrapped a total of 605 articles associated with Bernie Sanders. Among those articles, 189 are sourced from the New York Times; 216 are sourced from The Washington Post; and 200 are sourced from the Wall Street Journal.

# %%
# generate a balanced dataset for Sanders
dfSanders_balanced = balanced_dataset(dfSanders, 150)

# %%
# export to csv
# set directory path
path_for_all_candidate = "C:/Users/Winnie/Documents/2020 Spring/NLP/Final Project/Data/All_Candidates/"

# export csv file
dfSanders_balanced.to_csv(path_for_all_candidate + 'Bernie_Sanders.csv', index = False)

# %% [markdown]
# ## Donald Trump

# %%
PATH_Trump = "C:/Users/Winnie/Documents/2020 Spring/NLP/Final Project/Data/Trump"
CANDIDATE_NAME_Trump = 'Donald Trump'
dfTrump, unique_names = individual_candidate_articles(PATH_Trump, CANDIDATE_NAME_Trump)
dfTrump.head(2)
# Out:
#                                                title  \
# 0  Primary Battles on the Right? They Seem Less S...
# 1  Collins Will Not Support Removal of the Presid...
#
#                                                 text           media  \
# 0  Hide highlightingFull TextTranslateUndo Transl...  New York Times
# 1  Full TextTranslateUndo Translation FromToTrans...  New York Times
#
#    word_count candidate_name
# 0      1880.0   Donald Trump
# 1      1066.0   Donald Trump

# %%
nNYT = len(dfTrump[dfTrump['media'] == 'New York Times'])
nTWP = len(dfTrump[dfTrump['media'] == 'The Washington Post'])
nWSJ = len(dfTrump[dfTrump['media'] == 'Wall Street Journal'])
n_total = len(dfTrump)

print('The unique news media company names are:', unique_names, 
      '. We scrapped a total of', n_total, 
      'articles associated with Donald Trump. Among those articles,',
      nNYT, 'are sourced from the New York Times;',
      nTWP, 'are sourced from The Washington Post; and',
      nWSJ, 'are sourced from the Wall Street Journal.')
# Out:
# The unique news media company names are: ['New York Times' 'The Washington Post' 'Wall Street Journal'] . We scrapped a total of 571 articles associated with Donald Trump. Among those articles, 175 are sourced from the New York Times; 196 are sourced from The Washington Post; and 200 are sourced from the Wall Street Journal.

# %%
# generate a balanced dataset for Sanders
dfTrump_balanced = balanced_dataset(dfTrump, 150)

# %%
# export to csv
dfTrump_balanced.to_csv(path_for_all_candidate + 'Donald_Trump.csv', index = False)

# %% [markdown]
# ## Joe Biden

# %%
PATH_Biden = "C:/Users/Winnie/Documents/2020 Spring/NLP/Final Project/Data/Biden"
CANDIDATE_NAME_Biden = 'Joe Biden'
dfBiden, unique_names = individual_candidate_articles(PATH_Biden, CANDIDATE_NAME_Biden)
dfBiden.head(2)
# Out:
#                                                title  \
# 0  Democrats Turn Focus To Trump's Intentions In ...
# 1  Sheâ€™s the Next President. Wait, Did You Read...
#
#                                                 text           media  \
# 0  Hide highlightingFull TextTranslateUndo Transl...  New York Times
# 1  Hide highlightingAbstractTranslateUndo Transla...  New York Times
#
#    word_count candidate_name
# 0      1667.0      Joe Biden
# 1      1594.0      Joe Biden

# %%
nNYT = len(dfTrump[dfTrump['media'] == 'New York Times'])
nTWP = len(dfTrump[dfTrump['media'] == 'The Washington Post'])
nWSJ = len(dfTrump[dfTrump['media'] == 'Wall Street Journal'])
n_total = len(dfTrump)

print('The unique news media company names are:', unique_names, 
      '. We scrapped a total of', n_total, 
      'articles associated with Joe Biden. Among those articles,',
      nNYT, 'are sourced from the New York Times;',
      nTWP, 'are sourced from The Washington Post; and',
      nWSJ, 'are sourced from the Wall Street Journal.')
# Out:
# The unique news media company names are: ['New York Times' 'The Washington Post' 'Wall Street Journal'] . We scrapped a total of 571 articles associated with Joe Biden. Among those articles, 175 are sourced from the New York Times; 196 are sourced from The Washington Post; and 200 are sourced from the Wall Street Journal.

# %%
# generate a balanced dataset for Sanders
dfBiden_balanced = balanced_dataset(dfBiden, 150)

# %%
# export to csv
dfBiden_balanced.to_csv(path_for_all_candidate + 'Joe_Biden.csv', index = False)

# %% [markdown]
# ## All Candidates

# %%
df_all = pd.concat([dfSanders_balanced, dfTrump_balanced, dfBiden_balanced], axis=0, ignore_index=True)
len(df_all)
# Out:
# 1350

# %%
df_all[751:800]
# Out:
#                                                  title  \
# 751  Trump Denounces Impeachment, Saying He 'Went T...
# 752  At CPAC, Battle Lines Are Drawn; With a theme ...
# 753  Iowa Caucus Results Delayed by Counting Proble...
# 754  Trump Campaign Targets Iowa to Show Strength, ...
# 755  House Sends Impeachment Charges to Senate for ...
# 756  Democrats, Trump Team Make Final Arguments in ...
# 757  Lev Parnas Paid His Way Into Donald Trump's Or...
# 758  The Trump-Bloomberg New York Story: Public War...
# 759  As Impeachment Nears End, Trump to Deliver Sta...
# 760  U.S. News: Trump Allows More Seasonal Guest Wo...
# 761  House to Send Articles of Impeachment to Senat...
# 762  Bios of Seven Democratic Impeachment Managers;...
# 763  Six Days in the Senate: How Democrats, Trump T...
# 764  Trump Rewards Vulnerable Senators for Loyalty ...
# 765  Facebook Removes Trump Campaign Ads, Citing Ce...
# 766  Trump, Democrats Gird for Fierce 2020 Fight in...
# 767  Stalled Initiatives to Cut Drug Prices Frustra...
# 768  Bolton Claim Set to Scramble Impeachment Proce...
# 769  U.S. News: Romney Goes Against Party in Vote t...
# 770  At CPAC, Battle Lines Are Drawn; With a theme ...
# 771  White House Expands Use of Cyber Weapons but S...
# 772      U.S. News: Facebook Removes 'Census' Trump Ad
# 773       U.S. News: Trump Rewards Vulnerable Senators
# 774  On Big Stage, Trump Aims Message at Black Vote...
# 775  U.S. News: President's Campaign Targets Iowa -...
# 776  Trump Lauds U.S. Economy as He Opens World Eco...
# 777  Michigan Democrats Will Offer General Election...
# 778  Democrats Present Case that Trump Impeded Cong...
# 779  Targeted Killing of Iranian General Puts U.S. ...
# 780  Bernie Sanders Was Warned Russia Is Trying to ...
# 781  Senate Acquits Trump on Both Impeachment Artic...
# 782  Prosecutors Quit Roger Stone Case After Justic...
# 783  Trump Sizes Up Sanders as Potential Opponent; ...
# 784  Trump Mideast Proposal Sees Two States --- Pla...
# 785  Trump's GOP Challengers Try to Catch Voters' A...
# 786  Trump Pardons Michael Milken, Commutes Sentenc...
# 787  Supreme Court Declines to Fast-Track Democrati...
# 788  Trump's Popularity Ticks Up During Coronavirus...
# 789  Trump Allies Push Donors in Effort to Countera...
# 790  Trump Campaign Works to Garner Local News Cove...
# 791  Targeted Killing of Iranian General Puts U.S. ...
# 792  U.S. News: Michigan Vote Offers First Look At ...
# 793  New Documents From Giuliani Associate Parnas S...
# 794  Americans Stuck to Their Views on Trump Throug...
# 795  The Trump-Bloomberg New York Story: Public War...
# 796  Trump's India Visit to Stress Personal Ties Ov...
# 797  Democrats Outline Case for Removing Trump; Fir...
# 798  Trump, Pence Show Off Contrasting Styles in Io...
# 799  New Documents From Giuliani Associate Parnas S...
#
#                                                   text                media  \
# 751  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 752  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 753  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 754  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 755  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 756  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 757  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 758  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 759  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 760  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 761  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 762  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 763  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 764  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 765  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 766  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 767  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 768  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 769  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 770  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 771  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 772  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 773  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 774  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 775  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 776  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 777  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 778  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 779  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 780  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 781  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 782  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 783  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 784  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 785  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 786  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 787  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 788  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 789  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 790  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 791  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 792  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 793  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 794  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 795  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 796  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 797  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 798  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
# 799  Hide highlightingFull TextTranslateUndo Transl...  Wall Street Journal
#
#      word_count candidate_name
# 751       921.0   Donald Trump
# 752       987.0   Donald Trump
# 753      1847.0   Donald Trump
# 754       779.0   Donald Trump
# 755      1661.0   Donald Trump
# 756       973.0   Donald Trump
# 757      2001.0   Donald Trump
# 758      2020.0   Donald Trump
# 759      1052.0   Donald Trump
# 760       520.0   Donald Trump
# 761      1132.0   Donald Trump
# 762       972.0   Donald Trump
# 763       746.0   Donald Trump
# 764      1015.0   Donald Trump
# 765       827.0   Donald Trump
# 766      1229.0   Donald Trump
# 767       995.0   Donald Trump
# 768      1450.0   Donald Trump
# 769       503.0   Donald Trump
# 770      1013.0   Donald Trump
# 771      1231.0   Donald Trump
# 772       576.0   Donald Trump
# 773       604.0   Donald Trump
# 774       992.0   Donald Trump
# 775       661.0   Donald Trump
# 776      1121.0   Donald Trump
# 777      1355.0   Donald Trump
# 778      1484.0   Donald Trump
# 779      1721.0   Donald Trump
# 780       928.0   Donald Trump
# 781      1394.0   Donald Trump
# 782      1023.0   Donald Trump
# 783       966.0   Donald Trump
# 784      1347.0   Donald Trump
# 785       651.0   Donald Trump
# 786      1315.0   Donald Trump
# 787       806.0   Donald Trump
# 788       569.0   Donald Trump
# 789      1009.0   Donald Trump
# 790       889.0   Donald Trump
# 791      1940.0   Donald Trump
# 792       934.0   Donald Trump
# 793      1004.0   Donald Trump
# 794       959.0   Donald Trump
# 795      2020.0   Donald Trump
# 796       908.0   Donald Trump
# 797       706.0   Donald Trump
# 798       930.0   Donald Trump
# 799      1105.0   Donald Trump
